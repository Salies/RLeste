# %%
from stable_baselines3 import DQN
from stable_baselines3.common.env_checker import check_env
import gymnasium as gym
from gymnasium import spaces
import numpy as np
from Pyleste.PICO8 import PICO8
from Pyleste.Carts.Celeste import Celeste
import Pyleste.CelesteUtils as utils
import random
import time

# %%
# auxiliary functions rewritten by me
def compute_displacement(player):
    sign = lambda x: 1 if x > 0 else -1 if x < 0 else 0
    dx, dy = round(player.rem.x + player.spd.x), round(player.rem.y + player.spd.y)
    dx, dy = dx + sign(dx), dy + sign(dy)
    while player.is_solid(dx, 0): dx -= sign(player.spd.x)
    while player.is_solid(dx, dy): dy -= sign(player.spd.y)
    return dx, dy

def action_restrictions(game, player):
    dx, dy = compute_displacement(player)
    h_movement = abs(player.spd.x) <= 1
    can_jump = not player.p_jump and (player.grace - 1 > 0 or player.is_solid(-3 + dx, dy) or player.is_solid(3 + dx, dy) or player.is_solid(dx, 1 + dy))
    can_dash = player.djump > 0 or player.is_solid(dx, 1 + dy) or player.check(game.balloon, 0, 0) or player.check(game.fruit, 0, 0) or player.check(game.fly_fruit, 0, 0)
    return h_movement, can_jump, can_dash

def eval_actions(h_movement, can_jump, can_dash):
    ''' button states
        0b000000 -  0 - no input
        0b000001 -  1 - l
        0b000010 -  2 - r
        0b010000 - 16 - z
        0b010001 - 17 - l + z
        0b010010 - 18 - r + z
        0b100000 - 32 - x
        0b100001 - 33 - l + x
        0b100010 - 34 - r + x
        0b100100 - 36 - u + x
        0b100101 - 37 - u + l + x
        0b100110 - 38 - u + r + x
        0b101000 - 40 - d + x
        0b101001 - 41 - d + l + x
        0b101010 - 42 - d + r + x
    '''
    actions = [0b000000] if not h_movement else [0b000000, 0b000001, 0b000010]
    if can_jump:
        actions.extend([0b010000] if not h_movement else [0b010000, 0b010001, 0b010010])
    if can_dash:
        actions.extend([0b100000, 0b100001, 0b100010, 0b100100, 0b100101, 0b100110, 0b101000, 0b101001, 0b101010])
    return actions


def get_possible_actions(p8):
    p = p8.game.get_player()

    if not p: # dead RIP :(
        return []

    if p.dash_time != 0: return [0b000000]
    return eval_actions(*action_restrictions(p8.game, p))

LEVEL_ID = 0
LEVEL_GOAL = (108, 0)
x_goal, y_goal = LEVEL_GOAL
FPS = 30
MAX_FRAMES = 1 * 60 * FPS
TIME_PENALTY = 1

ALL_ACTIONS = [
    0, 1, 2, 16, 17, 18, 32, 33, 34, 36, 37, 38, 40, 41, 42
]

class CelesteEnv(gym.Env):
    metadata = {'render.modes': ['human']}

    def __init__(self, time_penalty=TIME_PENALTY):
        super().__init__()
        self.time_penalty = time_penalty
        self.p8 = PICO8(Celeste)
        utils.load_room(self.p8, LEVEL_ID)
        utils.skip_player_spawn(self.p8)

        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf, shape=(6,), dtype=np.float32
        )

        self.action_space = spaces.Discrete(len(ALL_ACTIONS))

        self.frame_count = 0
        self.best_reward = -np.inf
        self.best_episode = []

    def reset(self, seed=None, options=None):
        utils.load_room(self.p8, LEVEL_ID)
        utils.skip_player_spawn(self.p8)
        self.frame_count = 0
        self.current_episode_actions = []
        return self._get_obs(), {}

    def _get_obs(self):
        p = self.p8.game.get_player()
        if not p:
            return np.array([
                *self.p8.game.last_player_pos,
                *self.p8.game.last_player_rem,
                *self.p8.game.last_player_spd
            ], dtype=np.float32)
        return np.array([
            p.x, p.y, p.rem.x, p.rem.y, p.spd.x, p.spd.y
        ], dtype=np.float32)

    def step(self, action_idx):
        action_value = ALL_ACTIONS[action_idx]
        self.p8.set_btn_state(action_value)
        self.p8.step()

        obs = self._get_obs()
        reward = self._compute_reward()
        terminated = self._check_termination()
        truncated = self.frame_count >= MAX_FRAMES

        self.current_episode_actions.append(action_value)
        self.frame_count += 1

        # save best episode
        if reward > self.best_reward:
            self.best_reward = reward
            self.best_episode = self.current_episode_actions.copy()

        return obs, reward, terminated, truncated, {}

    def _compute_reward(self):
        p = self.p8.game.get_player()
        reward = 0
        if not p:
            # death penalty
            reward -= 50
            x = self.p8.game.last_player_pos[0]
            y = self.p8.game.last_player_pos[1]
            spdx = self.p8.game.last_player_spd[0]
            spdy = self.p8.game.last_player_spd[1]
        else:
            x, y = p.x, p.y
            spdx, spdy = p.spd.x, p.spd.y
            # check if got strawberry
            if p.check(self.p8.game.fruit, 0, 0):
                reward += 200
        
        reward += (x) * 0.5
        reward += (128 - y) * 1
        reward += 1 * spdx
        reward += (-1) * 2 * spdy

        # time penalty
        reward -= self.time_penalty

        # distance bonus
        dist = ((x - x_goal) ** 2 + (y - y_goal) ** 2) ** 0.5
        reward += (160 - dist) * 0.5
        
        # huge goal for reaching y = 26
        if y <= 26 and x >= 90:
            reward += 300

        # MUDEI ISSO
        if y <= 10 and x >= 100:
            reward += 500

        reward /= 256
        
        return reward

    def _check_termination(self):
        p = self.p8.game.get_player()
        if not p:
            return True
        # goal check with vertical speed <= -0.5
        # MUDEI ISSO
        if (p.x >= LEVEL_GOAL[0] - 5 and p.y <= 5 - LEVEL_GOAL[1] and p.spd.y <= -0.5):
            print("I'M ACTUALLY FINISHED")
            return True
        return False

    def render(self, mode="human"):
        print(self.p8.game)

    def save_best_episode(self):
        # get current time
        filename = time.strftime("best_episode_%Y%m%d_%H%M%S.txt")
        filename = f"./out/lvl{LEVEL_ID}/" + filename
        with open(filename, "w") as f:
            for a in self.best_episode:
                f.write(f"{a}\n")

# %%
env = CelesteEnv()
print(check_env(env))
# Out:
# None

# %%
model = DQN(
    "MlpPolicy",
    env,
    learning_starts=1000,
    buffer_size=10_000,
    learning_rate=1e-3,
    batch_size=32,
    gamma=0.99,
    exploration_fraction=0.9,
    exploration_final_eps=0.05,
    target_update_interval=500,
    verbose=1,
    seed=661
)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=500_000)
env.save_best_episode()
# Out:
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 186      |
# |    ep_rew_mean      | 58       |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 25710    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 742      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 308      |
# |    ep_rew_mean      | 86.5     |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 5955     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2464     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0134   |
# |    n_updates        | 365      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 308      |
# |    ep_rew_mean      | 87       |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 4898     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3696     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0264   |
# |    n_updates        | 673      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 341      |
# |    ep_rew_mean      | 93.2     |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 4472     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5463     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0195   |
# |    n_updates        | 1115     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 350      |
# |    ep_rew_mean      | 98.2     |
# |    exploration_rate | 0.985    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 4349     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7003     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.22     |
# |    n_updates        | 1500     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 344      |
# |    ep_rew_mean      | 97.3     |
# |    exploration_rate | 0.983    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 4274     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8268     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0894   |
# |    n_updates        | 1816     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      |
|
# |    exploration_rate | 0.848    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 3721     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 72210    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 71.1     |
# |    n_updates        | 17802    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 211      |
# |    ep_rew_mean      | 68.3     |
# |    exploration_rate | 0.846    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 3718     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 72913    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 98.7     |
# |    n_updates        | 17978    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 214      |
# |    ep_rew_mean      | 70.1     |
# |    exploration_rate | 0.844    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 3713     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 74004    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 87.2     |
# |    n_updates        | 18250    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 220      |
# |    ep_rew_mean      | 71.3     |
# |    exploration_rate | 0.841    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 3704     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 75180    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 153      |
# |    n_updates        | 18544    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 222      |
# |    ep_rew_mean      | 71.9     |
# |    exploration_rate | 0.84     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 3700     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 76007    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 154      |
# |    n_updates        | 18751    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 233      |
# |    ep_rew_mean      | 74.3     |
# |    exploration_rate | 0.836    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 3692     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 77603    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 73       |
# |    n_updates        | 19150    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 242      |
# |    ep_rew_mean      | 76.2     |
# |    exploration_rate | 0.833    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 3690     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 78935    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 145      |
# |    n_updates        | 19483    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 244      |
# |    ep_rew_mean      | 77       |
# |    exploration_rate | 0.83     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 3687     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 80622    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 81.4     |
# |    n_updates        | 19905    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 245      |
# |    ep_rew_mean      | 76.4     |
# |    exploration_rate | 0.828    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 3686     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 81516    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 94.5     |
# |    n_updates        | 20128    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 231      |
# |    ep_rew_mean      | 71.3     |
# |    exploration_rate | 0.827    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 3685     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 82075    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 126      |
# |    n_updates        | 20268    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 231      |
# |    ep_rew_mean      | 71.8     |
# |    exploration_rate | 0.825    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 3682     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 82828    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 71.1     |
# |    n_updates        | 20456    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 229      |
# |    ep_rew_mean      | 70.5     |
# |    exploration_rate | 0.823    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 3678     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 83971    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 132      |
# |    n_updates        | 20742    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 232      |
# |    ep_rew_mean      | 71.3     |
# |    exploration_rate | 0.821    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 3675     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 84656    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 268      |
# |    n_updates        | 20913    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 238      |
# |    ep_rew_mean      | 72.7     |
# |    exploration_rate | 0.819    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 3672     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 85786    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 126      |
# |    n_updates        | 21196    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 237      |
# |    ep_rew_mean      | 72.5     |
# |    exploration_rate | 0.817    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 3669     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 86496    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 119      |
# |    n_updates        | 21373    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 232      |
# |    ep_rew_mean      | 70.8     |
# |    exploration_rate | 0.816    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 3667     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 87150    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 392      |
# |    n_updates        | 21537    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 231      |
# |    ep_rew_mean      | 70.6     |
# |    exploration_rate | 0.815    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 3665     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 87854    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 187      |
# |    n_updates        | 21713    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 233      |
# |    ep_rew_mean      | 71.2     |
# |    exploration_rate | 0.813    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 3663     |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 88630    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 484      |
# |    n_updates        | 21907    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 230      |
# |    ep_rew_mean      | 70.4     |
# |    exploration_rate | 0.812    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 3661     |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 89190    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 172      |
# |    n_updates        | 22047    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 227      |
# |    ep_rew_mean      | 69.4     |
# |    exploration_rate | 0.811    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 3659     |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 89598    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 169      |
# |    n_updates        | 22149    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 226      |
# |    ep_rew_mean      | 69.3     |
# |    exploration_rate | 0.809    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 3656     |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 90456    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 157      |
# |    n_updates        | 22363    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 226      |
# |    ep_rew_mean      | 69.7     |
# |    exploration_rate | 0.807    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 3655     |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 91395    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 589      |
# |    n_updates        | 22598    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 226      |
# |    ep_rew_mean      | 69.9     |
# |    exploration_rate | 0.806    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 3654     |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 91920    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 304      |
# |    n_updates        | 22729    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 222      |
# |    ep_rew_mean      | 69.5     |
# |    exploration_rate | 0.804    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 3651     |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 92672    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 462      |
# |    n_updates        | 22917    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 223      |
# |    ep_rew_mean      | 69.9     |
# |    exploration_rate | 0.803    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 3648     |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 93529    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 249      |
# |    n_updates        | 23132    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 218      |
# |    ep_rew_mean      | 68.9     |
# |    exploration_rate | 0.801    |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 3647     |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 94035    |
# ...
# |    time_elapsed     | 160      |
# |    total_timesteps  | 484357   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.15e+06 |
# |    n_updates        | 120839   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 107      |
# |    ep_rew_mean      | 42.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3212     |
# |    fps              | 3011     |
# |    time_elapsed     | 160      |
# |    total_timesteps  | 484539   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.17e+06 |
# |    n_updates        | 120884   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 108      |
# |    ep_rew_mean      | 42.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3216     |
# |    fps              | 3010     |
# |    time_elapsed     | 161      |
# |    total_timesteps  | 484827   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.38e+06 |
# |    n_updates        | 120956   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 107      |
# |    ep_rew_mean      | 42.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3220     |
# |    fps              | 3010     |
# |    time_elapsed     | 161      |
# |    total_timesteps  | 485009   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 8.17e+06 |
# |    n_updates        | 121002   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 106      |
# |    ep_rew_mean      | 41.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3224     |
# |    fps              | 3010     |
# |    time_elapsed     | 161      |
# |    total_timesteps  | 485430   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 8.23e+06 |
# |    n_updates        | 121107   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 109      |
# |    ep_rew_mean      | 43.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3228     |
# |    fps              | 3010     |
# |    time_elapsed     | 161      |
# |    total_timesteps  | 485901   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.28e+06 |
# |    n_updates        | 121225   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 111      |
# |    ep_rew_mean      | 45.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3232     |
# |    fps              | 3009     |
# |    time_elapsed     | 161      |
# |    total_timesteps  | 486588   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.05e+06 |
# |    n_updates        | 121396   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 111      |
# |    ep_rew_mean      | 45.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3236     |
# |    fps              | 3009     |
# |    time_elapsed     | 161      |
# |    total_timesteps  | 486757   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.59e+06 |
# |    n_updates        | 121439   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 109      |
# |    ep_rew_mean      | 44.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3240     |
# |    fps              | 3009     |
# |    time_elapsed     | 161      |
# |    total_timesteps  | 487041   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.84e+06 |
# |    n_updates        | 121510   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 114      |
# |    ep_rew_mean      | 44.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3244     |
# |    fps              | 3008     |
# |    time_elapsed     | 162      |
# |    total_timesteps  | 487748   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 9.13e+06 |
# |    n_updates        | 121686   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 128      |
# |    ep_rew_mean      | 51.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3248     |
# |    fps              | 3006     |
# |    time_elapsed     | 162      |
# |    total_timesteps  | 489343   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 9.46e+06 |
# |    n_updates        | 122085   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 128      |
# |    ep_rew_mean      | 51.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3252     |
# |    fps              | 3006     |
# |    time_elapsed     | 162      |
# |    total_timesteps  | 489541   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.78e+06 |
# |    n_updates        | 122135   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 130      |
# |    ep_rew_mean      | 54.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3256     |
# |    fps              | 3005     |
# |    time_elapsed     | 163      |
# |    total_timesteps  | 490498   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.83e+06 |
# |    n_updates        | 122374   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 131      |
# |    ep_rew_mean      | 55.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3260     |
# |    fps              | 3005     |
# |    time_elapsed     | 163      |
# |    total_timesteps  | 490903   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.27e+06 |
# |    n_updates        | 122475   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 130      |
# |    ep_rew_mean      | 54.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3264     |
# |    fps              | 3005     |
# |    time_elapsed     | 163      |
# |    total_timesteps  | 491068   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.8e+06  |
# |    n_updates        | 122516   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 126      |
# |    ep_rew_mean      | 54.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3268     |
# |    fps              | 3004     |
# |    time_elapsed     | 163      |
# |    total_timesteps  | 491306   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 8.07e+06 |
# |    n_updates        | 122576   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 122      |
# |    ep_rew_mean      | 53       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3272     |
# |    fps              | 3004     |
# |    time_elapsed     | 163      |
# |    total_timesteps  | 491467   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.5e+06  |
# |    n_updates        | 122616   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 118      |
# |    ep_rew_mean      | 50.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3276     |
# |    fps              | 3004     |
# |    time_elapsed     | 163      |
# |    total_timesteps  | 491792   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.8e+06  |
# |    n_updates        | 122697   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | 50.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3280     |
# |    fps              | 3003     |
# |    time_elapsed     | 163      |
# |    total_timesteps  | 492202   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.94e+06 |
# |    n_updates        | 122800   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 107      |
# |    ep_rew_mean      | 49.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3284     |
# |    fps              | 3003     |
# |    time_elapsed     | 163      |
# |    total_timesteps  | 492398   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.69e+06 |
# |    n_updates        | 122849   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 106      |
# |    ep_rew_mean      | 50.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3288     |
# |    fps              | 3002     |
# |    time_elapsed     | 164      |
# |    total_timesteps  | 493017   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.56e+06 |
# |    n_updates        | 123004   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 103      |
# |    ep_rew_mean      | 50.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3292     |
# |    fps              | 3002     |
# |    time_elapsed     | 164      |
# |    total_timesteps  | 493248   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.3e+06  |
# |    n_updates        | 123061   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | 49.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3296     |
# |    fps              | 3002     |
# |    time_elapsed     | 164      |
# |    total_timesteps  | 493399   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.51e+06 |
# |    n_updates        | 123099   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.5     |
# |    ep_rew_mean      | 47.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3300     |
# |    fps              | 3002     |
# |    time_elapsed     | 164      |
# |    total_timesteps  | 493730   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.63e+06 |
# |    n_updates        | 123182   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 104      |
# |    ep_rew_mean      | 49.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3304     |
# |    fps              | 3001     |
# |    time_elapsed     | 164      |
# |    total_timesteps  | 494440   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3e+06    |
# |    n_updates        | 123359   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 108      |
# |    ep_rew_mean      | 49.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3308     |
# |    fps              | 3001     |
# |    time_elapsed     | 164      |
# |    total_timesteps  | 495150   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.05e+06 |
# |    n_updates        | 123537   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 114      |
# |    ep_rew_mean      | 50.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3312     |
# |    fps              | 3000     |
# |    time_elapsed     | 165      |
# |    total_timesteps  | 495927   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 7.71e+06 |
# |    n_updates        | 123731   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 116      |
# |    ep_rew_mean      | 50.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3316     |
# |    fps              | 3000     |
# |    time_elapsed     | 165      |
# |    total_timesteps  | 496408   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.01e+06 |
# |    n_updates        | 123851   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 121      |
# |    ep_rew_mean      | 51.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3320     |
# |    fps              | 3000     |
# |    time_elapsed     | 165      |
# |    total_timesteps  | 497108   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.31e+06 |
# |    n_updates        | 124026   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 123      |
# |    ep_rew_mean      | 50.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3324     |
# |    fps              | 2999     |
# |    time_elapsed     | 165      |
# |    total_timesteps  | 497701   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.63e+06 |
# |    n_updates        | 124175   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | 52       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3328     |
# |    fps              | 2999     |
# |    time_elapsed     | 166      |
# |    total_timesteps  | 499328   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.47e+06 |
# |    n_updates        | 124581   |
# ----------------------------------

# %% [markdown]
# ## TODO:
# * deixar as recompensas gigantes um pouco mais autonomas (independente do level)
# * penalizar mais o tempo
# * portar pra Ray RLib pra ter action masking
# * moranguinhos?
